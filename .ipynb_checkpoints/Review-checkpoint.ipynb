# %% [markdown]
# # 语言技术，数据库，网络：
#
# - [X] 进程和线程的区别
#
# [Zhihu Answer](https://www.zhihu.com/question/25532384?sort=created)
#
# [Microsoft Answer](https://docs.microsoft.com/en-us/windows/desktop/procthread/processes-and-threads)
#
# - [X] TCP与UDP区别，三次握手，四次挥手解释下
#
# [Answer 1](https://www.cnblogs.com/steven520213/p/8005258.html)
#
# [Answer 2](https://www.cnblogs.com/xiaomayizoe/p/5258754.html)
#
# [English Answer 3](https://support.holmsecurity.com/hc/en-us/articles/212963869-What-is-the-difference-between-TCP-and-UDP-)
#
# - [X] C++ * & 与 函数的传值
#
# [CSDN Answer](http://www.cnblogs.com/mr-stn/p/9037773.html)
#
# [菜鸟函数传值](http://www.runoob.com/cplusplus/cpp-functions.html)
#
# [指针传递与引用传递的区别](https://www.cnblogs.com/dingxiaoqiang/p/8012578.html)
#
# - [X] C++基类，派生类，虚函数，多态性
#
# [基类，派生类](https://blog.csdn.net/weixin_37058227/article/details/80537692)
#
# [C++多态性](https://blog.csdn.net/qq_39412582/article/details/81628254)
#
# [虚函数表](https://blog.csdn.net/lyztyycode/article/details/81326699)
#
# - [X] C++ 智能指针一系列问题，引用计数如何实现
#
# [Answer1](https://www.cnblogs.com/QG-whz/p/4777312.html?utm_source=tuicool&utm_medium=referral)
#
# - [X] C++ 构造函数
#
# [菜鸟Answer](http://www.runoob.com/cplusplus/cpp-constructor-destructor.html)
#
# - [X] C++ 拷贝控制
#
# [CSDN Answer1](https://blog.csdn.net/hjxhjh/article/details/6330282)
#
# - [X] C++ 类中函数前后const的意义
#
# [Answer1](https://www.iteblog.com/archives/214.html)
#
# - [X] C++ 类，static的类有什么用
#
# [RUNOOB](http://www.runoob.com/cplusplus/cpp-classes-objects.html)
#
# [.,::,->](https://blog.csdn.net/k_koris/article/details/80469956)
#
# - [X] C++ Struct和Class区别，你更倾向于用哪一个
#
# [Answer1](https://www.cnblogs.com/ccsccs/articles/4025215.html)
#
# - [] C++ STL
#
# - [] C++ Vector, List,C++中vector增删改的时间复杂度（O(1)，O(n)，O(n)）
#
# - [] const * char p 与 char const * p含义
#
# - [X] Python的函数参数（传递）
#
# [可变传递与不可变传递](https://blog.csdn.net/midion9/article/details/51281918)
#
# [Runoob](http://www.runoob.com/python3/python3-data-type.html)
#
# - [X] Python打开一个文件时的with是干嘛的 ，在c++里对应的哪个机制，c++如何实现
#
# [Answer](https://www.cnblogs.com/DswCnblog/p/6126588.html)
#
# - [X] Python中协成的概念（即微线程，具体可以看廖雪峰的网站）
#
# [LiaoXueFeng](https://www.liaoxuefeng.com/wiki/0014316089557264a6b348958f449949df42a6d3a2e542c000/001432090171191d05dae6e129940518d1d6cf6eeaaa969000)
#
# -----

# %% [markdown]
# # 传统机器学习：
#
# - [X] P,NP,NP-C,NP-Hard
#
# [Matrix67](http://www.matrix67.com/blog/archives/105)
#
# - [X] 概率公式并讲解
#
# [贝叶斯公式](https://blog.csdn.net/qq_31073871/article/details/81077386)
#
# - [X] 朴素贝叶斯推导
#
# [Maximum A Posteriror](https://blog.csdn.net/xx_123_1_rj/article/details/82913079)
#
# [MAP and Maximum Likelihood Estimation](https://www.cnblogs.com/sylvanas2012/p/5058065.html)
#
# - [X] 分类的评价标准，准确度，召回率，AUC
#
# [Accuracy, Precision, Recall, ROC&AUC](https://blog.csdn.net/u013063099/article/details/80964865)
#
# - [X] DecisionTree
#
# GBDT
#
# XGboost
#
# LightGBM
#
# 树模型的特征选择中除了信息增益、信息增益比、基尼指数这三个外，还有哪些？
#
# [信息论-熵-KL散度](http://leijun00.github.io/2014/07/information-theory/)
#
# [KL散度与互信息](https://blog.csdn.net/ice110956/article/details/17120461)
#
# [协方差与相关系数](https://www.cnblogs.com/sanshanyin/p/5397091.html)
#
# [ID3,C4.5,CART](https://www.cnblogs.com/wxquare/p/5379970.html)
#
# [GBDT](https://www.cnblogs.com/wxquare/p/5372996.html)
#
# [GBDT,XGboost,LightGBM](https://www.cnblogs.com/mata123/p/7440774.html)
#
# [Adaboost,GBDT,XGBoost,LightGBM](https://blog.csdn.net/bbbeoy/article/details/79590981)
#
# [RandomForest](https://www.cnblogs.com/gczr/p/7097704.html)
#
# - [X] 逻辑回归(Logistic Regression)
#
# [Accuracy与Precision,Bias与Variance](https://blog.csdn.net/wokaowokaowokao12345/article/details/72830242)
#
# [中心极限定理与大数定理](https://blog.csdn.net/qq_25366173/article/details/80152161)
#
# [线性模型为何要用最小二乘法](https://blog.csdn.net/saltriver/article/details/57544704)
#
# [最小二乘法的矩阵求导解](https://blog.csdn.net/u011893609/article/details/80016915)
#
# [Logistic Regression](https://blog.csdn.net/t46414704152abc/article/details/79574003)
#
# - [X] 偏差和方差的区别，模型Ensemble
#
# [Zhihu, Bagging and Boosting](https://www.zhihu.com/question/26760839)
#
# [Model Ensemble](https://www.cnblogs.com/xxiaolige/p/9285862.html)
#
# - [X] GMM原理
#
# [EM算法](https://www.jianshu.com/p/c57ef1508fa7)
#
# [统计学习方法EM]()
#
# - [X] KNN+Kmeans
#
# [Answer1](https://www.cnblogs.com/pinard/p/6164214.html)
#
# - [X] L1与L2区别？L1为啥具有稀疏性？
#
# L2正则的本质？限制解空间范围，缩小解空间，控制模型复杂度
#
# [L0,L1,L2](https://blog.csdn.net/zouxy09/article/details/24971995)
#
# [Zhihu:关于L1与L2正则在x=0处的稀疏性的优美解释](https://www.zhihu.com/question/37096933/answer/70426653)
#
# [核函数与规则项参数](https://blog.csdn.net/zouxy09/article/details/24972869)
#
# - [X] SVM(马马虎虎)
#
# LIBSVM
#
# rankSVM
#
# SVM引入核函数本质？提高维度，增加模型复杂度
#
# [Zhihu 1](https://zhuanlan.zhihu.com/p/24638007)
#
# [Zhihu 2](https://zhuanlan.zhihu.com/p/29865057)
#
# [Answer3](https://blog.csdn.net/b285795298/article/details/81977271)
#
# - [X] 隐式马尔科夫HMM
#
# [直观的基础](https://www.cnblogs.com/skyme/p/4651331.html)
#
# [统计学习方法HMM]()
#
# [如何保存状态](https://blog.csdn.net/zb1165048017/article/details/48578183)

# %% [markdown]
# # 深度学习：
#
# - [] Pytorch, Numpy
#
# - [] 过拟合与欠拟合
#
# 欠拟合的解决方法？模型简单，加深神经网络，svm用核函数等等
#
# - [] CNN
#
# 卷积,卷积网络中参数量、运算量的计算,如何计算感受野
#
# 池化
#
# Dropout,Dropout 层的原理、应用
#
# Batch Normalisation,BN层的原理、应用，训练和测试时的设置
#
# Case:ResNet的原理,GoogleNet&VGG,YOLO一类方法与RCNN一类方法的主要区别
#
# - [] Softmax Loss推一下
#
# - [] 各种优化算法
#
# 梯度下降和随机梯度下降的区别？
#
# 牛顿法和拟牛顿法的区别？
#
# 为啥提出拟牛顿？因为牛顿法涉及海塞矩阵，它的逆矩阵求解很麻烦
#
# 比较
#
# SGD 中 S(stochastic)代表什么?个人理解差不多就是Full-Batch和Mini-Batch
#
# 梯度消失的原因
#
# - [] GAN
#
# 描述GAN，包括流程、Loss函数、生成器和判别器的结构,GAN与之前方法（如VAE）的比较GAN的引申，描述一下比如DCGAN，WGAN（因为我说看过WGAN，所以让我讲了一下WGAN解决的两个问题以及如何解决的）
#
# VAE
#
# Case:cycleGAN, WGAN
#
# - [] 模型压缩
#
# 讲一下MobileNet，如何减少模型参数量
#
#
# - [] RNN
#
# LSTM比RNN的优势
#
# - [] 数据
#
# 数据不平衡怎么解决，有哪些重采样方法
#
# 模型复杂度与测试机error的关系
#
# 训练集大小与测试机error的关系
#
# - [] 模型预训练中的学习率设置，为何可以进行预训练
#
# -----

# %% [markdown]
# # 算法+数据结构：
#
#
# - [X] Tree
#
# 二叉树非递归中序遍历
#
# 寻找二叉树的公共父节点
#
# 判断一棵树是否是另一棵的子树
#
# 树的广度、深度遍历
#
# 二叉查找树，二叉平衡树，B-树，B+树，红黑树
#
# [Introduction](https://blog.csdn.net/qq_32690999/article/details/80484440)
#
# - [X] Huffman Tree
#
# 原理
#
# 其在ML中的应用
#
# [Huffman Tree](https://www.cnblogs.com/kubixuesheng/p/4397798.html)
#
# - [X] Two Pointers
#
# 有序数组a[1,...,n]，和一个数m, 问a中有没有两个数相加等于m(以及各种变形模式)
#
# - [X] Math
#
# Faboonachi算法以及加速实现方法
#
# - [X] Hash
#
# 给你一个只由0和1组成的字符串，找一个最长的子串，要求这个子串里面0和1的数目相等。时间O(n)
#
# - [X] String
#
# KMP算法
#
# 翻转字符串
#
# 求一个字符串的最长回文子串.时间复杂度可以到O(n) (Manacher算法)
#
# atoi()：将字符串转换为整型值。
#
# 但是题目中有要求只能向字符串的末尾插入字符串，使得新字符串是最短的回文串，不是向任意位置插入...KMP
#
# [最长回文子串DP和Manacher算法](https://www.cnblogs.com/mini-coconut/p/9074315.html)
#
# [KMP](https://www.cnblogs.com/yjiyjige/p/3263858.html)
#
# - [X] Linked List
#
# [关于链表的环判断，环入口，两个链表的相交](https://blog.csdn.net/u010983881/article/details/78896293)
#
# - [X] Array
#
# 排序数组rotate一次后，查找某个数 O(logn)
#
# 数组中出现次数超过一半的数 O(n)
#
# 找数组中2个出现两次的数字，还有3个两次的数字 O(n)
#
# 给你一个数组以及一个数K， 从这个数组里面选择三个数，使得三个数的和小于等于K， 问有多少种选择的方法？O(n^2)
#
# 一串首尾相连的珠子(m 个)，有 N 种颜色(N<=10)，取出其中一段，要求包含所有 N 中颜色，并使长度最短。O(n)
#
# - [X] Heap
#
# 求无序数组的中位数 (nlogn)
#
# [Python Document](https://docs.python.org/3/library/heapq.html)
#
# - [X] Sort
#
# [各种排序算法比较](https://www.cnblogs.com/zhaoshuai1215/p/3448154.html)
#
# - [X] Bit Manipulation
#
# 从日志中找出IP出现次数超过1024次的恶意IP (分治，Hash）
#
# 10 亿个整数，1G 内存，O(n) 算法，统计只出现一次的数（位图法，分治法，Has）
#
# 给 10^10 个 64 位数, 100M 内存的空间排序, 感谢队长刚好在去的前一天教过我一个求中位数的方法. （用文件操作来做了, 像快排一样, 二分选个数统计大于那个数的数量和小于那个数的数量, 如果能用 100M 的空间排序就把那些数排了, 如果不能继续. 直到能排为止.）
#
# - [] 矩阵操作
#
# 给你一个只由0和1组成的矩阵，找出一个最大的子矩阵，要求这个子矩阵是方阵，并且这个子矩阵的所有元素为1.时间复杂度可以到O(n^2)
#
# - [] 最短路径算法
#
# 最短路问题，第K条最短路
#
# - [] Dynamic Programming
#
# X 括号匹配 O(n) (DP or stack)
#
# X 最长上升子序列 O(n^2) DP==>O(nlogn)(trick, binary search)
#
# 求最长的无重复字母的子串
#
# 一个大小为N的数组，里面的值代表的是股价，求一次买入卖出所能够求得最大收益？如果是两次买入卖出呢？[动态规划解决](https://blog.csdn.net/jx_870915876/article/details/52587634)
#
# 给你一个数组，在这个数组中找出不重合的两段，让这两段的字段和的差的绝对值最大。时间复杂度可以到O(n)
#
# 给你一个数组，求这个数组的最大子段积.时间复杂度可以到O(n)
#
# 给你一个数组，求一个k值，使得前k个数的方差 + 后面n-k个数的方差最小.时间复杂度可以到O(n)
#
# - [] 杂
#
# 输入一个整数，反转输出:比如输入1234，然后输出4321。我给的答案。。
#
# N 个数找 K 大数那个题, 堆解释了一遍, 比较满意, 问还能怎么优化 O(Nlogk) 的方法，并行方面想
#
# 问一个字符串怎么判断是邮箱比如: `vzcxn@sdf.gre`. 有限状态自动机, 然后要我画状态转移图.
#
# 一个python的dict，按照key-value存储，如何按照value排序?如果是C++怎么做？一个map,怎么按照value排序？
#
# 求逆序对个数（暴力，归并，树状数组）
#
# 在一个数轴上移动，初始在0点，现在要到给定的某一个x点，每一步有三种选择，坐标加1，坐标减1，坐标乘以2，请问最少需要多少步从0点到x点。
#
# 给你一个集合，输出这个集合的所有子集。
#
# 写一个程序，在单位球面上随机取点，也就是说保证随机取到的点是均匀的。
#
# -----

# %% [markdown]
# # 高性能计算：
#
# - [] OpenMP
#
# - [] MPI
#
# - [] OpenCL
#
# # 项目：
#
# # 英语：
